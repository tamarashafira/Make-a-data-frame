# %% [markdown]
# # Package Pandas
#
# Digunakan untuk pengolahan data yang berkaitan dengan data frame.

# %%
# Lakukan import pandas sebagai pd
import pandas as pd

# %%
# Lakukan import numpy sebagai np
import numpy as np

# %% [markdown]
# ## 1. Membuat dataframe
#
# Untuk membuat data frame, digunakan sintaks berikut: `pandas.DataFrame( data, index, columns, dtype, copy)`
# 1. index merupakan label untuk baris
# 2. columns merupakan label untuk kolom
# 3. dtype merupakan tipe data perkolom
# 4. copy digunakan untuk menyalin data, defaultnya False

# %%
# Membuat rentang waktu
tanggal = pd.date_range("20200901", freq="M", periods=9)
print(tanggal)
# Out:
# DatetimeIndex(['2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# Membuat data frame dengan data randon ukuran 9x4, serta label baris adalah tanggal dan label kolom A, B, C, D
contoh1 = pd.DataFrame(np.random.randn(9,4), index=tanggal, columns=("A","B","C","D"))
contoh1
# Out:
#                    A         B         C         D
# 2020-09-30  1.807234 -0.546344 -0.393466 -0.353618
# 2020-10-31 -0.899886 -0.892469  0.614704  0.280939
# 2020-11-30  1.750727  0.016294  1.136336  0.703570
# 2020-12-31  2.480358  0.908032 -0.767740 -1.299337
# 2021-01-31 -1.225295  0.117517 -0.489437  0.488737
# 2021-02-28 -0.930417 -0.995462 -0.742580 -0.211376
# 2021-03-31 -0.090109  0.330262  1.023413  0.787451
# 2021-04-30  2.088013 -0.772923  1.308658  0.619509
# 2021-05-31  0.294834  1.541281  0.733460  0.886389

# %%
# Membuat dataframe dengan daftar anggota
contoh2 = pd.DataFrame({"A": 1.,
                       "B": pd.Timestamp("20180925"),
                       "C": np.array([3]*4, dtype="int32"),
                       "D": pd.Categorical(["test","train"]*2),
                       "E": np.array([1,12,32,14])}, index=["satu","dua","tiga","empat"])
contoh2
# Out:
#          A          B  C      D   E
# satu   1.0 2018-09-25  3   test   1
# dua    1.0 2018-09-25  3  train  12
# tiga   1.0 2018-09-25  3   test  32
# empat  1.0 2018-09-25  3  train  14

# %% [markdown]
# ## 2. Menambah, menghapus, dan menyeleksi kolom data frame
#
# Menghapus kolom dengan fungsi:
# 1. `del(data_frame["kolom"])`
# 2. `.pop("kolom")`
# 3. `.drop("kolom", axis=1)`; axis=1 berarti menghapus sepanjang kolom yang dimaksud
#
# Menambahkan kolom baru dengan operasi matematis "+"

# %%
# Menambahkan kolom baru dengan nama "F", dengan operasi penambahan kolom "C" dan "E"
contoh2["F"]=contoh2["C"]+contoh2["E"]
print(contoh2)
# Out:
#          A          B  C      D   E   F
# satu   1.0 2018-09-25  3   test   1   4
# dua    1.0 2018-09-25  3  train  12  15
# tiga   1.0 2018-09-25  3   test  32  35
# empat  1.0 2018-09-25  3  train  14  17

# %%
# Menambahkan kolom baru dengan nama "G", pada index satu, tiga, empat 
contoh2["G"]=pd.Series([10,20,30], index=["satu", "tiga", "empat"])
print(contoh2)
# Out:
#          A          B  C      D   E   F     G
# satu   1.0 2018-09-25  3   test   1   4  10.0
# dua    1.0 2018-09-25  3  train  12  15   NaN
# tiga   1.0 2018-09-25  3   test  32  35  20.0
# empat  1.0 2018-09-25  3  train  14  17  30.0

# %%
# Menghapus kolom "B" dengan fungsi del
del(contoh2["B"])
contoh2
# Out:
#          A  C      D   E   F     G
# satu   1.0  3   test   1   4  10.0
# dua    1.0  3  train  12  15   NaN
# tiga   1.0  3   test  32  35  20.0
# empat  1.0  3  train  14  17  30.0

# %%
# Menghapus kolom "C" dengan pop
contoh2.pop("C")
contoh2
# Out:
#          A      D   E   F     G
# satu   1.0   test   1   4  10.0
# dua    1.0  train  12  15   NaN
# tiga   1.0   test  32  35  20.0
# empat  1.0  train  14  17  30.0

# %%
# Menyeleksi kolom "A"
kolomA = contoh2["A"]
kolomA
# Out:
# satu     1.0
# dua      1.0
# tiga     1.0
# empat    1.0
# Name: A, dtype: float64

# %%
# Menghapus kolom "A" dengan fungsi drop
contoh2_hapus = contoh2.drop("A", axis = 1)
contoh2_hapus.head()
# Out:
#            D   E   F     G
# satu    test   1   4  10.0
# dua    train  12  15   NaN
# tiga    test  32  35  20.0
# empat  train  14  17  30.0

# %% [markdown]
# ## 3. Menambah, mengurang, dan menyeleksi baris pada data frame
#
# Menyeleksi/mengiris data frame dengan fungsi:
# 1. `loc`: untuk seleksi dengan menggunakan indeks/bilangan bulat
# 2. `iloc`: untuk seleksi dengan menggunakan bilangan bulat
#
# Menambah baris dengan fungsi: `.append()`
#
# Menghapus baris dengan fungsi: `.del("index", axis=0)`, axis=0 berarti menghapus sepanjang baris.

# %%
# Menambah baris menggunakan fungsi append
contoh3 = pd.DataFrame([[1,"train",4,5,6.0], [2,"test",7,12,34]], columns=["A","D","E","F","G"])
contoh3

contoh4 = contoh2.append(contoh3)
contoh4
# Out:
#          A      D   E   F     G
# satu   1.0   test   1   4  10.0
# dua    1.0  train  12  15   NaN
# tiga   1.0   test  32  35  20.0
# empat  1.0  train  14  17  30.0
# 0      1.0  train   4   5   6.0
# 1      2.0   test   7  12  34.0

# %%
# Menyeleksi indeks "tiga" pada baris
contoh4.loc["tiga"]
# Out:
# A       1
# D    test
# E      32
# F      35
# G      20
# Name: tiga, dtype: object

# %%
# Menyeleksi baris ke 2 dan 3, dengan menyebut urutannya, kemudian mengcopy hasilnya
contoh5=contoh4.iloc[1:3].copy()
contoh5
# Out:
#         A      D   E   F     G
# dua   1.0  train  12  15   NaN
# tiga  1.0   test  32  35  20.0

# %%
# Menghapus baris dengan indeks "tiga". Simpan variabel dengan nama "contoh5_hapus"
contoh5_hapus = contoh5.drop("tiga", axis=0)
contoh5_hapus
# Out:
#        A      D   E   F   G
# dua  1.0  train  12  15 NaN

# %% [markdown]
# ## 4. Menyeleksi/megiris data frame berdasar baris dan kolom

# %%
contoh2
# Out:
#          A      D   E   F     G
# satu   1.0   test   1   4  10.0
# dua    1.0  train  12  15   NaN
# tiga   1.0   test  32  35  20.0
# empat  1.0  train  14  17  30.0

# %%
# mengiris data baris dan kolom
contoh2.iloc[1:3, 2:5]
# Out:
#        E   F     G
# dua   12  15   NaN
# tiga  32  35  20.0

# %%
# Menampilkan informasi pada data frame
contoh2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, satu to empat
# Data columns (total 5 columns):
# A    4 non-null float64
# D    4 non-null category
# E    4 non-null int32
# F    4 non-null int32
# G    3 non-null float64
# dtypes: category(1), float64(2), int32(2)
# memory usage: 388.0+ bytes

# %% [markdown]
# ### Fungsi dasar untuk series
#
#
# Berikut fungsi dasar untuk series (deret)
#
# No   | Fungsi   | Deskripsi
# :---:|:---      |:---
# 1    | axes     | Daftar label baris dan kolom |
# 2    | dtypes   | Daftar tipe data setiap kolom |
# 3    | empty    | Akan bernilai True jika deret ada yang kosong |
# 4    | size     | Ukuran dari data |
# 5    | values   | Mengubah deret menjadi ndarray (n dimensional array) |
# 6    | head()   | Menampilkan n data pertama |
# 7    | tail()   | Menampilkan n data terakhir |

# %%
# cobalah fungsi axes, dtypes, empty, size, head, tail untuk contoh2

# %% [markdown]
# ## 5. Mengimport atau membaca file (csv, xls)

# %%
# Membaca file xls. File terletak dalam satu folder dengan notebook jupyter
superstore = pd.read_excel("Superstore.xls")
superstore.head()
# Out:
#    Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0      18  ID-2014-44908 2014-02-26 2014-03-04  Standard Class    AI-10855
# 1      19  ID-2014-44908 2014-02-26 2014-03-04  Standard Class    AI-10855
# 2      20  ID-2012-73146 2012-10-24 2012-10-30  Standard Class    HM-14980
# 3      21  ID-2012-73146 2012-10-24 2012-10-30  Standard Class    HM-14980
# 4      24  ID-2012-57809 2012-10-09 2012-10-13  Standard Class    AO-10810
#
#        Customer Name    Segment       Kota       State    Country  \
# 0     Arianne Irving   Consumer    Bandung  Jawa Barat  Indonesia
# 1     Arianne Irving   Consumer    Bandung  Jawa Barat  Indonesia
# 2  Henry MacAllister   Consumer   Denpasar        Bali  Indonesia
# 3  Henry MacAllister   Consumer   Denpasar        Bali  Indonesia
# 4  Anthony O'Donnell  Corporate  Pekanbaru        Riau  Indonesia
#
#            Region       Product ID         Category Sub-Category  \
# 0  Southeast Asia  OFF-SU-10004848  Office Supplies     Supplies
# 1  Southeast Asia  OFF-PA-10003332  Office Supplies        Paper
# 2  Southeast Asia  OFF-AP-10000487  Office Supplies   Appliances
# 3  Southeast Asia  OFF-LA-10000095  Office Supplies       Labels
# 4  Southeast Asia  FUR-TA-10000665        Furniture       Tables
#
#                                    Product Name      Sales  Quantity  \
# 0                   Kleencut Shears, High Speed   123.9405         5
# 1             Xerox Cards & Envelopes, Recycled    47.5728         2
# 2                          Hoover Stove, Silver  1417.3578         3
# 3  Avery Round Labels, Laser Printer Compatible    22.7052         6
# 4         Bevis Computer Table, Fully Assembled   786.2868         3
#
#    Discount    Profit
# 0      0.47  -84.2595
# 1      0.47  -15.3072
# 2      0.17 -290.3022
# 3      0.47   -4.2948
# 4      0.47 -563.8032

# %%
# Gunakan fungsi dasar untuk series, untuk melihat informasi tabel
superstore.empty
# Out:
# False

# %%
superstore.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Kota                     object
# State                    object
# Country                  object
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
# Ukuran data frame (baris, kolom)
superstore.shape
# Out:
# (1388, 20)

# %%
# Ukuran data frame 
superstore.size
# Out:
# 27760

# %%
# apakah tipe data superstore? Gunakan fungsi type
type(superstore)
# Out:
# pandas.core.frame.DataFrame

# %%
# Gunakan fungsi .info() untuk mengetahui gambaran data superstore
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388 entries, 0 to 1387
# Data columns (total 20 columns):
# Row ID           1388 non-null int64
# Order ID         1388 non-null object
# Order Date       1388 non-null datetime64[ns]
# Ship Date        1388 non-null datetime64[ns]
# Ship Mode        1388 non-null object
# Customer ID      1388 non-null object
# Customer Name    1388 non-null object
# Segment          1388 non-null object
# Kota             1388 non-null object
# State            1388 non-null object
# Country          1388 non-null object
# Region           1388 non-null object
# Product ID       1388 non-null object
# Category         1388 non-null object
# Sub-Category     1388 non-null object
# Product Name     1388 non-null object
# Sales            1388 non-null float64
# Quantity         1388 non-null int64
# Discount         1388 non-null float64
# Profit           1388 non-null float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(13)
# memory usage: 217.0+ KB

# %%
# Pilih kolom "Product Name", dan simpan dalam variabel produk

produk = superstore['Product Name']
produk.head(10)
# Out:
# 0                     Kleencut Shears, High Speed
# 1               Xerox Cards & Envelopes, Recycled
# 2                            Hoover Stove, Silver
# 3    Avery Round Labels, Laser Printer Compatible
# 4           Bevis Computer Table, Fully Assembled
# 5                     Sanford Canvas, Fluorescent
# 6     Binney & Smith Pencil Sharpener, Easy-Erase
# 7                Novimex Swivel Stool, Adjustable
# 8                   Panasonic Calculator, Durable
# 9                         Stockwell Clamps, Metal
# Name: Product Name, dtype: object

# %%
# Menjadikan series ke array dengan .values
produk.values
# Out:
# array(['Kleencut Shears, High Speed', 'Xerox Cards & Envelopes, Recycled',
#        'Hoover Stove, Silver', ..., 'Hon Chairmat, Set of Two',
#        'Rubbermaid Light Bulb, Black', 'Enermax Keyboard, Programmable'],
#       dtype=object)

# %%
superstore.iloc[::5, :].head(10)
# Out:
#     Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       18  ID-2014-44908 2014-02-26 2014-03-04  Standard Class    AI-10855
# 5       25  ID-2012-57809 2012-10-09 2012-10-13  Standard Class    AO-10810
# 10      98  ID-2011-74721 2011-05-04 2011-05-05     First Class    HG-14845
# 15     115  ID-2011-36011 2011-01-26 2011-01-27     First Class    HK-14890
# 20     158  IN-2014-17489 2014-12-22 2014-12-26  Standard Class    DF-13135
# 25     199  IN-2014-76450 2014-11-17 2014-11-21  Standard Class    PJ-19015
# 30     229  ID-2014-61169 2014-12-12 2014-12-16  Standard Class    EB-13930
# 35     298  ID-2013-22025 2013-10-09 2013-10-13  Standard Class    TS-21655
# 40     307  ID-2013-70122 2013-06-11 2013-06-15  Standard Class    AD-10180
# 45     326  IN-2014-54211 2014-01-16 2014-01-20  Standard Class    KB-16315
#
#         Customer Name      Segment        Kota             State    Country  \
# 0      Arianne Irving     Consumer     Bandung        Jawa Barat  Indonesia
# 5   Anthony O'Donnell    Corporate   Pekanbaru              Riau  Indonesia
# 10       Harry Greene     Consumer  Yogyakarta        Yogyakarta  Indonesia
# 15   Heather Kirkland    Corporate       Depok        Jawa Barat  Indonesia
# 20     David Flashing     Consumer      Jember        Jawa Timur  Indonesia
# 25    Pauline Johnson     Consumer   Pontianak  Kalimantan Barat  Indonesia
# 30       Eric Barreto     Consumer     Jakarta           Jakarta  Indonesia
# 35      Trudy Schmidt     Consumer     Bandung        Jawa Barat  Indonesia
# 40     Alan Dominguez  Home Office     Jakarta           Jakarta  Indonesia
# 45         Karl Braun     Consumer      Bekasi        Jawa Barat  Indonesia
#
#             Region       Product ID         Category Sub-Category  \
# 0   Southeast Asia  OFF-SU-10004848  Office Supplies     Supplies
# 5   Southeast Asia  OFF-AR-10001232  Office Supplies          Art
# 10  Southeast Asia  OFF-AP-10002017  Office Supplies   Appliances
# 15  Southeast Asia  FUR-CH-10003950        Furniture       Chairs
# 20  Southeast Asia  OFF-AR-10000539  Office Supplies          Art
# 25  Southeast Asia  OFF-BI-10004666  Office Supplies      Binders
# 30  Southeast Asia  OFF-EN-10002700  Office Supplies    Envelopes
# 35  Southeast Asia  TEC-CO-10000821       Technology      Copiers
# 40  Southeast Asia  FUR-CH-10002061        Furniture       Chairs
# 45  Southeast Asia  OFF-BI-10004869  Office Supplies      Binders
#
#                                          Product Name      Sales  Quantity  \
# 0                         Kleencut Shears, High Speed   123.9405         5
# 5                         Sanford Canvas, Fluorescent    75.5988         2
# 10                             Cuisinart Blender, Red    55.6017         1
# 15          Novimex Executive Leather Armchair, Black   334.3035         1
# 20                         Boston Markers, Easy-Erase    58.3416         3
# 25              Wilson Jones Binding Machine, Durable   125.6454         3
# 30  Kraft Interoffice Envelope, with clear poly wi...    80.2314         3
# 35                              Canon Ink, High-Speed   675.8775         5
# 40  Harbour Creations Executive Leather Armchair, Red  3126.4002         9
# 45                       Avery 3-Hole Punch, Recycled    93.7236         4
#
#     Discount    Profit
# 0       0.47  -84.2595
# 5       0.27    4.1388
# 10      0.17    0.6417
# 15      0.27 -109.9365
# 20      0.27  -15.9984
# 25      0.17   42.3054
# 30      0.47  -18.2286
# 35      0.07  -43.6725
# 40      0.27 -128.7198
# 45      0.17   34.9236

# %%
# Memilih baris kelipatan 3, dengan semua kolom. Kemudian tampilkan 10 data pertama
superstore.iloc[::3,:].head(10)
# Out:
#     Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       18  ID-2014-44908 2014-02-26 2014-03-04  Standard Class    AI-10855
# 3       21  ID-2012-73146 2012-10-24 2012-10-30  Standard Class    HM-14980
# 6       26  IN-2013-76464 2013-06-12 2013-06-14     First Class    DK-13090
# 9       97  ID-2011-74721 2011-05-04 2011-05-05     First Class    HG-14845
# 12     110  ID-2012-10230 2012-07-06 2012-07-09     First Class    JC-16105
# 15     115  ID-2011-36011 2011-01-26 2011-01-27     First Class    HK-14890
# 18     131  ID-2012-60427 2012-07-14 2012-07-20  Standard Class    RB-19795
# 21     178  ID-2013-52370 2013-05-29 2013-06-02  Standard Class    JR-15670
# 24     192  IN-2012-21297 2012-09-21 2012-09-28  Standard Class    ES-14080
# 27     211  IN-2013-29676 2013-01-17 2013-01-22  Standard Class    SS-20515
#
#         Customer Name      Segment        Kota             State    Country  \
# 0      Arianne Irving     Consumer     Bandung        Jawa Barat  Indonesia
# 3   Henry MacAllister     Consumer    Denpasar              Bali  Indonesia
# 6           Dave Kipp     Consumer    Semarang       Jawa Tengah  Indonesia
# 9        Harry Greene     Consumer  Yogyakarta        Yogyakarta  Indonesia
# 12    Julie Creighton    Corporate     Jakarta           Jakarta  Indonesia
# 15   Heather Kirkland    Corporate       Depok        Jawa Barat  Indonesia
# 18         Ross Baird  Home Office   Palembang  Sumatera Selatan  Indonesia
# 21        Jim Radford     Consumer     Jakarta           Jakarta  Indonesia
# 24         Erin Smith    Corporate   Surakarta       Jawa Tengah  Indonesia
# 27    Shirley Schmidt  Home Office    Jayapura             Papua  Indonesia
#
#             Region       Product ID         Category Sub-Category  \
# 0   Southeast Asia  OFF-SU-10004848  Office Supplies     Supplies
# 3   Southeast Asia  OFF-LA-10000095  Office Supplies       Labels
# 6   Southeast Asia  OFF-AR-10000027  Office Supplies          Art
# 9   Southeast Asia  OFF-FA-10001010  Office Supplies    Fasteners
# 12  Southeast Asia  OFF-LA-10004062  Office Supplies       Labels
# 15  Southeast Asia  FUR-CH-10003950        Furniture       Chairs
# 18  Southeast Asia  TEC-AC-10001022       Technology  Accessories
# 21  Southeast Asia  OFF-BI-10002881  Office Supplies      Binders
# 24  Southeast Asia  OFF-ST-10000485  Office Supplies      Storage
# 27  Southeast Asia  FUR-CH-10003232        Furniture       Chairs
#
#                                          Product Name      Sales  Quantity  \
# 0                         Kleencut Shears, High Speed   123.9405         5
# 3        Avery Round Labels, Laser Printer Compatible    22.7052         6
# 6         Binney & Smith Pencil Sharpener, Easy-Erase    61.1667         3
# 9                             Stockwell Clamps, Metal    82.0440         8
# 12               Hon Removable Labels, 5000 Label Set    16.3134         3
# 15          Novimex Executive Leather Armchair, Black   334.3035         1
# 18                           SanDisk Flash Drive, USB   105.3375         5
# 21              Wilson Jones Binding Machine, Economy    40.6368         1
# 24                     Fellowes Folders, Single Width    87.7476         4
# 27  Harbour Creations Executive Leather Armchair, ...  1375.8456         4
#
#     Discount    Profit
# 0       0.47  -84.2595
# 3       0.47   -4.2948
# 6       0.27   10.0467
# 9       0.47  -32.6760
# 12      0.47   -0.3366
# 15      0.27 -109.9365
# 18      0.47  -53.6625
# 21      0.17   -7.3632
# 24      0.17    6.2676
# 27      0.27   94.1256

# %%
# Menyeleksi data dengan Kota adalah "Semarang". Kemudian tampilkan 5 data pertama
semarang = superstore[superstore.Kota == "Semarang"]
semarang.head(5)
# Out:
#     Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 6       26  IN-2013-76464 2013-06-12 2013-06-14     First Class    DK-13090
# 7       27  IN-2013-76464 2013-06-12 2013-06-14     First Class    DK-13090
# 16     126  IN-2012-53175 2012-06-18 2012-06-23  Standard Class    BO-11350
# 17     127  IN-2012-53175 2012-06-18 2012-06-23  Standard Class    BO-11350
# 86     865  IN-2011-74070 2011-06-23 2011-06-25     First Class    CA-12265
#
#          Customer Name    Segment      Kota        State    Country  \
# 6            Dave Kipp   Consumer  Semarang  Jawa Tengah  Indonesia
# 7            Dave Kipp   Consumer  Semarang  Jawa Tengah  Indonesia
# 16       Bill Overfelt  Corporate  Semarang  Jawa Tengah  Indonesia
# 17       Bill Overfelt  Corporate  Semarang  Jawa Tengah  Indonesia
# 86  Christina Anderson   Consumer  Semarang  Jawa Tengah  Indonesia
#
#             Region       Product ID         Category Sub-Category  \
# 6   Southeast Asia  OFF-AR-10000027  Office Supplies          Art
# 7   Southeast Asia  FUR-CH-10003009        Furniture       Chairs
# 16  Southeast Asia  TEC-PH-10004509       Technology       Phones
# 17  Southeast Asia  OFF-FA-10002597  Office Supplies    Fasteners
# 86  Southeast Asia  TEC-PH-10002916       Technology       Phones
#
#                                    Product Name     Sales  Quantity  Discount  \
# 6   Binney & Smith Pencil Sharpener, Easy-Erase   61.1667         3      0.27
# 7              Novimex Swivel Stool, Adjustable  243.7470         2      0.27
# 16                   Nokia Audio Dock, Cordless  140.7597         1      0.17
# 17                          OIC Clamps, 12 Pack  142.4640        14      0.47
# 86          Apple Speaker Phone, with Caller ID  102.3390         1      0.17
#
#       Profit
# 6    10.0467
# 7    -6.6930
# 16   25.4097
# 17 -121.2960
# 86   30.8190

# %% [markdown]
# ## 6. Menambahkan kolom baru pada data frame

# %%
# Tambahkan kolom "Garansi", dan isikan semua baris dengan "Tidak Bergaransi"
superstore["Garansi"] = "Tidak bergaransi"
superstore.head(3)
# Out:
#    Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0      18  ID-2014-44908 2014-02-26 2014-03-04  Standard Class    AI-10855
# 1      19  ID-2014-44908 2014-02-26 2014-03-04  Standard Class    AI-10855
# 2      20  ID-2012-73146 2012-10-24 2012-10-30  Standard Class    HM-14980
#
#        Customer Name   Segment      Kota       State  ...          Region  \
# 0     Arianne Irving  Consumer   Bandung  Jawa Barat  ...  Southeast Asia
# 1     Arianne Irving  Consumer   Bandung  Jawa Barat  ...  Southeast Asia
# 2  Henry MacAllister  Consumer  Denpasar        Bali  ...  Southeast Asia
#
#         Product ID         Category Sub-Category  \
# 0  OFF-SU-10004848  Office Supplies     Supplies
# 1  OFF-PA-10003332  Office Supplies        Paper
# 2  OFF-AP-10000487  Office Supplies   Appliances
#
#                         Product Name      Sales  Quantity  Discount    Profit  \
# 0        Kleencut Shears, High Speed   123.9405         5      0.47  -84.2595
# 1  Xerox Cards & Envelopes, Recycled    47.5728         2      0.47  -15.3072
# 2               Hoover Stove, Silver  1417.3578         3      0.17 -290.3022
#
#             Garansi
# 0  Tidak bergaransi
# 1  Tidak bergaransi
# 2  Tidak bergaransi
#
# [3 rows x 21 columns]

# %%
# Seleksi kolom Customer ID, Kota, Sub-Category, dan Profit. Simpan dalam variabel superstore2
superstore2 = superstore[["Customer ID", "Kota", "Sub-Category", "Profit"]]
superstore2.head(5)
# Out:
#   Customer ID       Kota Sub-Category    Profit
# 0    AI-10855    Bandung     Supplies  -84.2595
# 1    AI-10855    Bandung        Paper  -15.3072
# 2    HM-14980   Denpasar   Appliances -290.3022
# 3    HM-14980   Denpasar       Labels   -4.2948
# 4    AO-10810  Pekanbaru       Tables -563.8032

# %%
# Seleksi superstore2, yang Kota adalah Semarang, memiliki Profit lebih dari 20. Simpan dalam superstore2_filter. 
superstore2_filter = superstore2[(superstore2.Kota == "Semarang") & (superstore2.Profit > 20)] 
superstore2_filter.head()
# Out:
#     Customer ID      Kota Sub-Category    Profit
# 16     BO-11350  Semarang       Phones   25.4097
# 86     CA-12265  Semarang       Phones   30.8190
# 99     CY-12745  Semarang       Chairs   28.4106
# 184    DP-13165  Semarang   Appliances  232.0011
# 230    MY-17380  Semarang   Appliances   70.7259

# %%
# Berapakah data yang sesuai dengan kondisi setelah dilakukan filtering? 
superstore2_filter.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61db200df4d7> in <module>
#       1 # Berapakah data yang sesuai dengan kondisi setelah dilakukan filtering?
# ----> 2 superstore2_filter.count()
#
# NameError: name 'superstore2_filter' is not defined

# %%
superstore_ = superstore[(superstore.State == "Jawa Timur")| (superstore.Sales > 2000)]
superstore_
# Out:
#       Row ID       Order ID Order Date  Ship Date       Ship Mode Customer ID  \
#
# 1250    9174  IN-2011-43634 2011-12-03 2011-12-07  Standard Class    JB-15925
# 1251    9175  ID-2014-34254 2014-11-04 2014-11-11  Standard Class    BF-11170
# 1252    9176  ID-2014-34254 2014-11-04 2014-11-11  Standard Class    BF-11170
# 1253    9178  IN-2014-69296 2014-09-13 2014-09-19  Standard Class    MN-17935
# 1260    9231  IN-2013-79992 2013-03-05 2013-03-12  Standard Class    TS-21505
# 1261    9232  IN-2012-77724 2012-09-16 2012-09-20  Standard Class    SC-20695
# 1286    9328  IN-2014-27933 2014-07-22 2014-07-29  Standard Class    KM-16660
# 1290    9332  ID-2012-39903 2012-01-02 2012-01-06  Standard Class    JS-15595
# 1303    9408  IN-2014-11287 2014-11-13 2014-11-16     First Class    FH-14350
# 1308    9462  IN-2014-34422 2014-03-04 2014-03-08  Standard Class    AS-10045
# 1322    9575  ID-2013-15963 2013-01-12 2013-01-16  Standard Class    FM-14215
# 1366    9832  ID-2014-49696 2014-10-20 2014-10-24  Standard Class    DN-13690
# 1367    9833  ID-2014-49696 2014-10-20 2014-10-24  Standard Class    DN-13690
# 1382    9945  ID-2012-23936 2012-08-13 2012-08-17  Standard Class    JM-16195
# 1387    9984  ID-2014-18147 2014-06-11 2014-06-13     First Class    JF-15190
#
#                Customer Name      Segment         Kota                State  \
# 19            David Flashing     Consumer       Jember           Jawa Timur
# 20            David Flashing     Consumer       Jember           Jawa Timur
# 32              Rose O'Brian     Consumer  Probolinggo           Jawa Timur
# 33                 Janet Lee     Consumer     Surabaya           Jawa Timur
# 36            Alan Dominguez  Home Office      Jakarta              Jakarta
# 40            Alan Dominguez  Home Office      Jakarta              Jakarta
# 56                Art Foster     Consumer     Surabaya           Jawa Timur
# 57           Susan Vittorini     Consumer     Surabaya           Jawa Timur
# 58           Susan Vittorini     Consumer     Surabaya           Jawa Timur
# 60              Frank Hawley    Corporate         Palu      Sulawesi Tengah
# 64            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 65            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 66            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 67            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 68            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 69            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 70            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 71            Thea Hendricks     Consumer     Surabaya           Jawa Timur
# 75             Paul Gonzalez     Consumer       Jember           Jawa Timur
# 76             Paul Gonzalez     Consumer       Jember           Jawa Timur
# 77             Paul Gonzalez     Consumer       Jember           Jawa Timur
# 92           Laura Armstrong    Corporate    Palembang     Sumatera Selatan
# 96            Aaron Smayling    Corporate  Probolinggo           Jawa Timur
# 98                 Joy Bell-     Consumer      Mataram  Nusa Tenggara Barat
# 110          Darrin Van Huff    Corporate       Manado       Sulawesi Utara
# 113              Bryan Mills     Consumer       Kediri           Jawa Timur
# 114         Dianna Vittorini     Consumer     Surabaya           Jawa Timur
# 115         Dianna Vittorini     Consumer     Surabaya           Jawa Timur
# 116           David Flashing     Consumer     Surabaya           Jawa Timur
# 117           David Flashing     Consumer     Surabaya           Jawa Timur
# ...                      ...          ...          ...                  ...
# 1175        Bruce Degenhardt     Consumer     Surabaya           Jawa Timur
# 1183          Alice McCarthy    Corporate     Surabaya           Jawa Timur
# 1188           Sibella Parks    Corporate       Jember           Jawa Timur
# 1189             Meg Tillman     Consumer  Probolinggo           Jawa Timur
# 1190             Chuck Clark  Home Office     Surabaya           Jawa Timur
# 32                               Tenex Frame, Erganomic   158.5560         2
# 33                    Avery Shipping Labels, Adjustable    20.6700         4
# 36              Lesro Conference Table, Fully Assembled  2276.4825         5
# 40    Harbour Creations Executive Leather Armchair, Red  3126.4002         9
# 56              Novimex Steel Folding Chair, Set of Two   555.0336         9
# 57                      Safco Library with Doors, Metal  2534.0175         7
# 58                     Boston Highlighters, Water Color    32.1930         2
# 60                Dania Library with Doors, Traditional  3707.3520        11
# 64                           Breville Microwave, Silver   502.0836         2
# 65                       Hewlett Personal Copier, Color   406.5309         3
# 66                                   Brother Ink, Color   691.6410         5
# 67                        Green Bar Memo Slips, Premium    17.9670         2
# 68         Binney & Smith Pencil Sharpener, Fluorescent    58.4073         3
# 69             Barricks Computer Table, Fully Assembled   254.0343         1
# 70                Office Star Rocking Chair, Adjustable   418.7280         4
# 71                          Memorex Keyboard, Erganomic   109.9485         3
# 75                   Dania Corner Shelving, Traditional   681.1506         6
# 76                                Acco Binder, Recycled    12.8733         1
# 77                            Acco Binder Covers, Clear    53.0370         5
# 92          Bevis Conference Table, with Bottom Storage  3427.1496         7
# 96              SAFCO Executive Leather Armchair, Black   670.1400         2
# 98                      Motorola Smart Phone, Full Size  3200.5962         6
# 110                    Safco Library with Doors, Mobile  2189.0898         6
# 113                                Okidata Phone, White   495.3606         7
# 114                                 Smead Lockers, Blue   329.3772         2
# 115                  Cardinal Binding Machine, Recycled    83.2158         2
# 116                   Lesro Training Table, Rectangular   705.8805         5
# 117                       Apple Speaker Phone, Cordless   314.1135         3
# ...                                                 ...        ...       ...
# 1175                              Smead Box, Industrial    28.0125         3
# 1183             Binney & Smith Sketch Pad, Fluorescent   312.6006         9
# 1188                      BIC Highlighters, Fluorescent    58.9548         4
# 1189                         Stockwell Push Pins, Metal    44.8380         6
# 1190                            Belkin Mouse, Erganomic    40.8312         2
# 1191                      Samsung Audio Dock, Full Size   418.6188         3
# 1192       Harbour Creations Round Labels, Alphabetical     6.9642         2
# 1193       Binney & Smith Pencil Sharpener, Water Color    39.3324         2
# 1197                                Enermax Router, USB   137.0262         1
# 1198                    Brother Fax Machine, High-Speed   589.1364         2
# 1199                     Ibico Binding Machine, Durable   131.7708         3
# 1200                         Novimex Rocking Chair, Red   575.6634         6
# 1215  GlobeWeis Interoffice Envelope, with clear pol...    54.4416         2
# 1248                                Ibico Binder, Clear    24.8004         2
# 1249              Safco Library with Doors, Traditional   362.5047         1
# 1250                Eaton Cards & Envelopes, Multicolor    74.0781         3
# 1251        Jiffy Peel and Seal, with clear poly window    49.9260         4
# 1252                   Dania Library with Doors, Mobile   678.7512         2
# 1253                        Ames Mailers, Security-Tint   101.3625         5
# 1260                      Cuisinart Refrigerator, White  2051.0130         5
# 1261                       Sauder Corner Shelving, Pine   276.4890         2
# 1286                    Sauder Classic Bookcase, Mobile  2039.0715         5
# 1290                                Hoover Stove, White  2821.7178         6
# 1303                      Brother Fax and Copier, Laser   712.3428         4
# 1308                        Ikea Corner Shelving, Metal   227.8872         2
# 1322                 Chromcraft Wood Table, Rectangular  2035.5816         8
# 1366                  SanDisk Message Books, Multicolor    26.7438         2
# 1367                           Stanley Sketch Pad, Blue   259.4712         8
# 1382                         Belkin Numeric Keypad, USB   117.7872         4
# 1387                     Enermax Keyboard, Programmable    90.0576         2
#
#       Discount     Profit           Garansi
# 19        0.17    57.0036  Tidak bergaransi
# 20        0.27   -15.9984  Tidak bergaransi
# 32        0.27   -26.0640  Tidak bergaransi
# 33        0.47    -8.9700  Tidak bergaransi
# 36        0.47  -472.5675  Tidak bergaransi
# 40        0.27  -128.7198  Tidak bergaransi
# 56        0.27  -175.0464  Tidak bergaransi
# 57        0.07   136.2375  Tidak bergaransi
# 58        0.27    -8.4270  Tidak bergaransi
# 60        0.07  1554.4320  Tidak bergaransi
# 64        0.17   -48.4164  Tidak bergaransi
# 65        0.07   166.0509  Tidak bergaransi
# 66        0.07   -15.0090  Tidak bergaransi
# 67        0.47    -4.1130  Tidak bergaransi
# 68        0.27    12.7773  Tidak bergaransi
# 69        0.47   -95.8857  Tidak bergaransi
# 70        0.27  -143.4720  Tidak bergaransi
# 71        0.47   -18.7515  Tidak bergaransi
# 75        0.07    21.8106  Tidak bergaransi
# 76        0.17    -2.0367  Tidak bergaransi
# 77        0.17   -10.8630  Tidak bergaransi
# 92        0.47  -452.8104  Tidak bergaransi
# 96        0.27  -128.5200  Tidak bergaransi
# 98        0.17   -77.2038  Tidak bergaransi
# 110       0.07   541.3698  Tidak bergaransi
# 113       0.17   149.0706  Tidak bergaransi
# 114       0.17    -7.9428  Tidak bergaransi
# 115       0.17    29.0358  Tidak bergaransi
# 116       0.47  -506.1195  Tidak bergaransi
# 117       0.17    30.2535  Tidak bergaransi
# ...        ...        ...               ...
# 1175      0.17    10.7325  Tidak bergaransi
# 1183      0.27     4.2606  Tidak bergaransi
# 1188      0.27   -11.3652  Tidak bergaransi
# 1189      0.47    -5.2020  Tidak bergaransi
# 1190      0.47   -19.2888  Tidak bergaransi
# 1191      0.17   105.8688  Tidak bergaransi
# 1192      0.47    -4.9158  Tidak bergaransi
# 1193      0.27     8.0724  Tidak bergaransi
# 1197      0.47   -46.5438  Tidak bergaransi
# 1198      0.07    25.3164  Tidak bergaransi
# 1199      0.17    38.0808  Tidak bergaransi
# 1200      0.27  -149.9166  Tidak bergaransi
# 1215      0.47   -33.9384  Tidak bergaransi
# 1248      0.17     8.9604  Tidak bergaransi
# 1249      0.07    74.0547  Tidak bergaransi
# 1250      0.47   -30.7719  Tidak bergaransi
# 1251      0.47   -13.1940  Tidak bergaransi
# 1252      0.07    72.9312  Tidak bergaransi
# 1253      0.47     1.9125  Tidak bergaransi
# 1260      0.17   667.1130  Tidak bergaransi
# 1261      0.07    32.6490  Tidak bergaransi
# 1286      0.07   109.6215  Tidak bergaransi
# 1290      0.17   339.8778  Tidak bergaransi
# 1303      0.07    91.8228  Tidak bergaransi
# 1308      0.07     4.8672  Tidak bergaransi
# 1322      0.47  -499.2984  Tidak bergaransi
# 1366      0.47   -22.2162  Tidak bergaransi
# 1367      0.27    49.7112  Tidak bergaransi
# 1382      0.47  -104.4528  Tidak bergaransi
# 1387      0.47   -28.9224  Tidak bergaransi
#
# [212 rows x 21 columns]
